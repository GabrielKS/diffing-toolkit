# %% [markdown]
# # ADL Results Explorer
#
# Explores Logit Lens and PatchScope outputs from the Activation Difference Lens pipeline.

# %%
from pathlib import Path

# --- Configuration (edit these) ---
RESULTS_DIR = Path("/workspace/model-organisms/diffing_results/gemma3_1B/cake_bake/activation_difference_lens")
LAYER = 12
DATASET = "fineweb-1m-sample"
LOGIT_LENS_POSITION = 8     # Position for per-position logit lens view
PATCHSCOPE_POSITION = 4     # Position for per-position patchscope view
N_POSITIONS = 128            # Total positions (config: n)
LOGIT_LENS_MAX_ROWS = None   # Set to an integer to truncate logit lens tables
PATCHSCOPE_GRADER = "openai_gpt-5-mini"
MODEL_ID = "google/gemma-3-1b-it"

LAYER_DIR = RESULTS_DIR / f"layer_{LAYER}" / DATASET

# %%
import re
import torch
import pandas as pd
from collections import defaultdict
from transformers import AutoTokenizer

pd.set_option("display.max_rows", 200)
pd.set_option("display.max_colwidth", 60)

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)


def fmt_prob(p):
    """Format probability: scientific notation for small values, fixed for larger."""
    if abs(p) < 0.01:
        return f"{p:.2e}"
    return f"{p:.4f}"


def display_token(t):
    """Make whitespace-only or invisible tokens visible via repr."""
    if not t.strip():
        return repr(t)
    return t


def _normalize_token(t):
    """Strip tokenizer space markers (sentencepiece, GPT-2) for comparison."""
    return t.replace("\u2581", "").replace("\u0120", "").strip()


def load_logit_lens(pos, prefix=""):
    """Load logit lens .pt file. Returns (top_k_probs, top_k_indices, inv_probs, inv_indices)."""
    return torch.load(LAYER_DIR / f"{prefix}logit_lens_pos_{pos}.pt", weights_only=True)


def decode_tokens(indices):
    return [tokenizer.decode([int(i)]) for i in indices]


def load_patchscope(pos, prefix=""):
    """Load auto_patch_scope .pt file. Returns dict with tokens_at_best_scale, selected_tokens, etc."""
    return torch.load(
        LAYER_DIR / f"{prefix}auto_patch_scope_pos_{pos}_{PATCHSCOPE_GRADER}.pt",
        weights_only=False,
    )


def discover_patchscope_positions():
    """Find which positions have patchscope results (diff variant)."""
    positions = []
    for f in sorted(LAYER_DIR.glob(f"auto_patch_scope_pos_*_{PATCHSCOPE_GRADER}.pt")):
        m = re.search(r"auto_patch_scope_pos_(\d+)_", f.name)
        if m:
            positions.append(int(m.group(1)))
    return positions


print(f"Layer dir: {LAYER_DIR}")
print(f"PatchScope positions: {discover_patchscope_positions()}")
# Out:
# Layer dir: /workspace/model-organisms/diffing_results/gemma3_1B/cake_bake/activation_difference_lens/layer_12/fineweb-1m-sample
# PatchScope positions: [0, 1, 2, 3, 4, 5]

# %% [markdown]
# ## 1. Logit Lens Analysis

# %% [markdown]
# ### 1A. Single Position
#
# Each column shows the top-100 (or bottom-100 for `_inv`) tokens from the logit lens projection.
# Format: `token (softmax_prob)`

# %%
# Logit lens columns: (file prefix, tuple index for probs, tuple index for indices)
LL_VARIANTS = {
    "base":     ("base_", 0, 1),
    "base_inv": ("base_", 2, 3),
    "ft":       ("ft_",   0, 1),
    "ft_inv":   ("ft_",   2, 3),
    "diff":     ("",      0, 1),
    "diff_inv": ("",      2, 3),
}


def logit_lens_position_table(pos):
    cols = {}
    for col_name, (prefix, pi, ii) in LL_VARIANTS.items():
        data = load_logit_lens(pos, prefix)
        tokens = decode_tokens(data[ii])
        probs = data[pi].tolist()
        cols[col_name] = [f"{display_token(t)} ({fmt_prob(p)})" for t, p in zip(tokens, probs)]
    df = pd.DataFrame(cols)
    if LOGIT_LENS_MAX_ROWS is not None:
        df = df.head(LOGIT_LENS_MAX_ROWS)
    return df


print(f"Logit lens at position {LOGIT_LENS_POSITION}:")
logit_lens_position_table(LOGIT_LENS_POSITION)
# Out:
# Logit lens at position 8:
#                      base                     base_inv                     ft  \
# 0          ' ' (9.77e-04)                 瑢 (8.01e-05)         ' ' (7.86e-04)
# 1          een (4.92e-04)     resetCounters (7.30e-05)         een (4.22e-04)
# 2           in (4.08e-04)                 琚 (7.06e-05)          in (3.28e-04)
# 3           on (2.80e-04)           scaleOf (6.87e-05)          on (2.43e-04)
# 4           في (2.63e-04)       <unused378> (6.44e-05)         the (2.43e-04)
# 5          the (2.59e-04)           dissati (6.25e-05)          في (1.93e-04)
# 6            a (2.18e-04)                 瑭 (5.87e-05)           a (1.84e-04)
# 7           to (2.15e-04)              llrp (5.60e-05)        give (1.84e-04)
# 8         have (2.12e-04)      subparagraph (5.51e-05)          to (1.75e-04)
# 9          for (1.93e-04)           صہیونیت (5.51e-05)        have (1.75e-04)
# 10        give (1.90e-04)       <unused403> (5.44e-05)         for (1.57e-04)
# 11          de (1.81e-04)                 俔 (5.34e-05)          de (1.53e-04)
# 12          من (1.75e-04)           wwwpond (5.34e-05)        want (1.48e-04)
# 13         بال (1.70e-04)      setToDefault (5.34e-05)        from (1.36e-04)
# 14        that (1.62e-04)       bibnamefont (5.34e-05)        that (1.29e-04)
# 15           ل (1.62e-04)      <unused1967> (5.17e-05)         two (1.26e-04)
# 16        from (1.54e-04)            namani (4.94e-05)         auf (1.26e-04)
# 17        want (1.41e-04)              ccgi (4.86e-05)           ل (1.24e-04)
# 18        with (1.41e-04)    fillColorSpace (4.86e-05)          în (1.22e-04)
# 19         auf (1.38e-04)       <unused389> (4.79e-05)        with (1.19e-04)
# 20          în (1.36e-04)      <unused1877> (4.79e-05)         one (1.19e-04)
# 21         one (1.31e-04)              کروچ (4.79e-05)          من (1.15e-04)
# 22          of (1.26e-04)            تباينه (4.79e-05)         بال (1.13e-04)
# 23           в (1.21e-04)       <unused375> (4.72e-05)          of (1.05e-04)
# 24         two (1.19e-04)               CCc (4.72e-05)        voor (1.02e-04)
# 25           ک (1.17e-04)            Старки (4.65e-05)        moet (1.00e-04)
# 26           ' (1.12e-04)              Fmat (4.58e-05)           ک (1.00e-04)
# 27           ر (1.10e-04)                 녠 (4.58e-05)          یک (9.82e-05)
# 28          یک (1.06e-04)                 瑗 (4.58e-05)      chciał (9.54e-05)
# 29          لل (1.06e-04)           textBox (4.51e-05)          at (9.39e-05)
# 30        voor (1.04e-04)      <unused1709> (4.51e-05)         dua (9.39e-05)
# 31        moet (1.03e-04)       <unused290> (4.36e-05)           в (9.25e-05)
# 25              ... (3.04e-07)
# 26             abit (3.04e-07)
# 27               /* (2.68e-07)
# 28              все (1.84e-07)
# 29              است (1.84e-07)
# 30                / (1.84e-07)
# 31              पुर (1.63e-07)
# 32              уже (1.63e-07)
# 33              при (1.43e-07)
# 34              або (1.43e-07)
# 35     bijvoorbeeld (1.43e-07)
# 36             tane (1.27e-07)
# 37                ( (1.27e-07)
# 38           beetje (1.12e-07)
# 39              الت (1.12e-07)
# 40              وال (9.87e-08)
# 41            ‌هایی (9.87e-08)
# 42   éventuellement (8.71e-08)
# 43           oppure (7.68e-08)
# 44              без (5.29e-08)
# 45              nào (5.29e-08)
# 46            queue (4.66e-08)
# 47             пока (4.12e-08)
# 48           обычно (3.40e-08)
# 49                ت (3.19e-08)
# 50           either (3.00e-08)
# 51               من (3.00e-08)
# 52         ailleurs (3.00e-08)
# 53          maioria (3.00e-08)
# 54           ничего (2.83e-08)
# 55             অনেক (2.83e-08)
# 56              بال (2.83e-08)
# 57             Some (2.83e-08)
# 58              或其他 (2.65e-08)
# 59                ف (2.49e-08)
# 60            pouco (2.34e-08)
# 61             ades (2.34e-08)
# 62            किंवा (1.94e-08)
# 63            leuke (1.94e-08)
# 64              que (1.83e-08)
# 65            altro (1.83e-08)
# 66               وت (1.71e-08)
# 67           invece (1.42e-08)
# 68         comunque (1.42e-08)
# 69             some (1.33e-08)
# 70                ड़ (1.25e-08)
# 71        eventuali (1.18e-08)
# 72            tengo (1.18e-08)
# 73            нагру (1.11e-08)
# 74             some (1.11e-08)
# 75             يمكن (1.11e-08)
# 76               не (1.11e-08)
# 77              เลย (1.04e-08)
# 78              ంగా (9.78e-09)
# 79                n (9.20e-09)
# 80                َ (8.61e-09)
# 81               או (8.09e-09)
# 82           quindi (7.63e-09)
# 83               ** (7.63e-09)
# 84               رخ (7.63e-09)
# 85               اس (7.13e-09)
# 86              الم (6.72e-09)
# 87             aber (6.72e-09)
# 88                n (6.32e-09)
# 89              على (5.91e-09)
# 90         proposés (5.56e-09)
# 91             plus (5.56e-09)
# 92               或者 (5.56e-09)
# 93             গুলো (5.56e-09)
# 94                " (5.24e-09)
# 95             nebo (5.24e-09)
# 96                . (4.92e-09)
# 97               रो (4.92e-09)
# 98               và (4.92e-09)
# 99               کا (4.92e-09)

# %% [markdown]
# ### 1B. Aggregated Across All Positions
#
# For each column, tokens are ranked by their average probability across all positions (tokens not in the top/bottom 100 for a given position contribute p=0).
# Format: `token (avg_prob)`

# %%
def logit_lens_aggregated():
    agg = {}
    for col_name, (prefix, pi, ii) in LL_VARIANTS.items():
        token_prob_sum = defaultdict(float)
        for pos in range(N_POSITIONS):
            data = load_logit_lens(pos, prefix)
            tokens = decode_tokens(data[ii])
            probs = data[pi].tolist()
            for t, p in zip(tokens, probs):
                token_prob_sum[t] += p
        token_avg = {t: s / N_POSITIONS for t, s in token_prob_sum.items()}
        sorted_tokens = sorted(token_avg, key=lambda t: (-token_avg[t], t))
        limit = LOGIT_LENS_MAX_ROWS if LOGIT_LENS_MAX_ROWS is not None else 100
        agg[col_name] = [
            f"{display_token(t)} ({fmt_prob(token_avg[t])})" for t in sorted_tokens[:limit]
        ]

    max_len = max(len(v) for v in agg.values())
    for k in agg:
        agg[k] += [""] * (max_len - len(agg[k]))
    return pd.DataFrame(agg)


print("Logit lens aggregated across all positions:")
logit_lens_aggregated()
# Out:
# Logit lens aggregated across all positions:
#                    base                     base_inv                     ft  \
# 0        ' ' (8.35e-04)     resetCounters (5.68e-05)         ' ' (2.98e-04)
# 1         in (4.75e-04)                 瑢 (5.37e-05)        give (2.81e-04)
# 2        the (4.10e-04)            namani (5.01e-05)         een (2.65e-04)
# 3        een (3.93e-04)                 瑭 (5.00e-05)         the (2.24e-04)
# 4         on (3.73e-04)                 琚 (4.64e-05)          in (2.18e-04)
# 5         to (3.53e-04)           dissati (4.61e-05)          on (1.99e-04)
# 6          a (3.44e-04)           scaleOf (4.52e-05)        have (1.89e-04)
# 7       give (3.38e-04)      setToDefault (4.46e-05)           a (1.74e-04)
# 8       have (3.12e-04)                 瑗 (4.40e-05)         one (1.62e-04)
# 9       that (2.95e-04)       bibnamefont (4.33e-05)        more (1.57e-04)
# 10       for (2.21e-04)          foresaid (4.31e-05)        want (1.57e-04)
# 11      more (2.05e-04)                 및 (4.15e-05)          to (1.44e-04)
# 12       one (1.93e-04)              کروچ (4.10e-05)        that (1.43e-04)
# 13      want (1.79e-04)            nbhost (3.99e-05)         auf (1.10e-04)
# 14       auf (1.73e-04)            تباينه (3.96e-05)         two (1.09e-04)
# 15      from (1.69e-04)                 녠 (3.93e-05)        make (1.08e-04)
# 16        de (1.50e-04)           textBox (3.87e-05)         for (1.04e-04)
# 17      with (1.39e-04)           صہیونیت (3.86e-05)      giving (1.01e-04)
# 18        at (1.36e-04)                 沄 (3.81e-05)      almost (9.99e-05)
# 19        في (1.32e-04)      subparagraph (3.81e-05)         dua (9.76e-05)
# 20        it (1.28e-04)                 俔 (3.80e-05)          at (9.11e-05)
# 21       two (1.20e-04)            Старки (3.79e-05)        tiga (8.74e-05)
# 22        of (1.18e-04)      activeButton (3.75e-05)      chciał (8.60e-05)
# 23      make (1.17e-04)           wwwpond (3.67e-05)        from (8.09e-05)
# 24    giving (1.13e-04)                 疃 (3.66e-05)        with (7.76e-05)
# 25        be (1.05e-04)              ايبي (3.63e-05)          في (7.75e-05)
# 26      will (1.01e-04)     ServicePolicy (3.62e-05)         had (7.70e-05)
# 27         ل (9.98e-05)              llrp (3.58e-05)          de (7.42e-05)
# 28    almost (9.98e-05)           पुरंदरे (3.55e-05)      choose (7.35e-05)
# 29        as (9.92e-05)              ccgi (3.55e-05)        moet (7.18e-05)
# 30       had (9.75e-05)             ipari (3.53e-05)        eine (7.15e-05)
# 31      take (9.65e-05)       <unused378> (3.48e-05)        unul (7.11e-05)
# 32       you (9.44e-05)            andRow (3.46e-05)        take (7.10e-05)
# 33        من (9.26e-05)                 洺 (3.42e-05)        HAVE (6.85e-05)
# 34    choose (8.76e-05)   chargingStation (3.30e-05)          în (6.80e-05)
# 17             Các (3.70e-05)                 𒅊 (1.44e-03)
# 18             그리고 (3.68e-05)      transcendent (1.43e-03)
# 19         மற்றும் (3.67e-05)                 𒄁 (1.40e-03)
# 20              Kg (3.62e-05)                 𒉕 (1.38e-03)
# 21             そして (3.57e-05)                 𒆣 (1.26e-03)
# 22         scaleOf (3.54e-05)            VSTYPE (1.14e-03)
# 23             bzw (3.54e-05)             WMNCA (1.13e-03)
# 24             Các (3.43e-05)                 𒍌 (1.03e-03)
# 25             तथा (3.40e-05)                 𒆡 (9.94e-04)
# 26               洺 (3.37e-05)    groundbreaking (9.37e-04)
# 27               蚪 (3.36e-05)            Danger (9.04e-04)
# 28          namani (3.33e-05)              ッション (9.04e-04)
# 29           annah (3.30e-05)                 ꗫ (8.84e-04)
# 30           bilir (3.29e-05)                 𒀻 (7.79e-04)
# 31    subparagraph (3.26e-05)      StarSrvGroup (7.71e-04)
# 32           ipari (3.21e-05)    Polynucleaires (7.69e-04)
# 33        foresaid (3.18e-05)                 𒂤 (7.56e-04)
# 34             그런데 (3.10e-05)         momentous (7.40e-04)
# 35            html (3.07e-05)            Ioctrl (7.36e-04)
# 36         पुरंदरे (3.03e-05)                 𒀺 (7.36e-04)
# 37               疃 (3.01e-05)                 𒅾 (7.24e-04)
# 38            новь (2.99e-05)                 𒀣 (7.23e-04)
# 39           jších (2.97e-05)        tBleStatus (7.02e-04)
# 40               沄 (2.96e-05)                 𒅫 (7.01e-04)
# 41            aspx (2.95e-05)      <unused5170> (7.00e-04)
# 42               堃 (2.92e-05)                 𒈰 (6.88e-04)
# 43               ® (2.90e-05)                 𒂕 (6.82e-04)
# 44           quium (2.87e-05)                 𒈑 (6.77e-04)
# 45              $( (2.85e-05)      <unused2353> (6.65e-04)
# 46          astype (2.85e-05)      <unused6026> (6.60e-04)
# 47               飩 (2.85e-05)                 𒇅 (6.54e-04)
# 48              /* (2.84e-05)                優秀 (6.22e-04)
# 49              (= (2.80e-05)                 𒅼 (6.10e-04)
# 50       restantes (2.80e-05)      <unused4702> (5.94e-04)
# 51          holder (2.74e-05)      <unused5823> (5.90e-04)
# 52          घटनाएं (2.70e-05)                 𒃘 (5.86e-04)
# 53    glTranslatef (2.65e-05)                 𒑄 (5.84e-04)
# 54    SQLException (2.63e-05)                 𒑎 (5.82e-04)
# 55               俔 (2.61e-05)            payogo (5.73e-04)
# 56              kg (2.60e-05)      <unused4449> (5.69e-04)
# 57        Assuming (2.54e-05)      <unused4211> (5.68e-04)
# 58     variational (2.54e-05)                예술 (5.66e-04)
# 59            Além (2.47e-05)                 𒇀 (5.66e-04)
# 60             ਅਤੇ (2.44e-05)      <unused4984> (5.51e-04)
# 61           FIXME (2.43e-05)            KAKKIA (5.30e-04)
# 62         OGRAPHY (2.41e-05)     బ్లావెట్‌స్కీ (5.21e-04)
# 63              Те (2.40e-05)            trrecl (5.08e-04)
# 64             htm (2.39e-05)      <unused4542> (5.08e-04)
# 65    setToDefault (2.37e-05)      <unused3455> (5.01e-04)
# 66     bibnamefont (2.37e-05)                 𒉜 (4.94e-04)
# 67             mbh (2.36e-05)            pepper (4.84e-04)
# 68             $(\ (2.34e-05)                 𒅸 (4.79e-04)
# 69             PIB (2.25e-05)                 𒍨 (4.76e-04)
# 70           خستان (2.24e-05)      <unused2293> (4.73e-04)
# 71               峒 (2.23e-05)                 𒂰 (4.68e-04)
# 72  ratingBarStyle (2.21e-05)                 𒆇 (4.63e-04)
# 73   heterogeneous (2.18e-05)                 𒁞 (4.59e-04)
# 74          وغيرها (2.12e-05)           tpConst (4.58e-04)
# 75                (2.10e-05)          Imputted (4.32e-04)
# 76               © (2.07e-05)                 𒂙 (4.29e-04)
# 77        MLLoader (1.99e-05)      <unused3232> (4.00e-04)
# 78           Modem (1.99e-05)           testHDR (3.95e-04)
# 79   Questionnaire (1.98e-05)            exquis (3.95e-04)
# 80         dissati (1.98e-05)            hiqsol (3.85e-04)
# 81               ※ (1.92e-05)      <unused2906> (3.82e-04)
# 82            ちなみに (1.89e-05)                 𒆼 (3.81e-04)
# 83              và (1.89e-05)      <unused4753> (3.79e-04)
# 84   Alternatively (1.86e-05)         visionary (3.69e-04)
# 85              mg (1.84e-05)                 𒋭 (3.56e-04)
# 86            thew (1.82e-05)                 𒁨 (3.54e-04)
# 87              /+ (1.80e-05)       blockidcoin (3.52e-04)
# 88          นอกจาก (1.80e-05)                 𒑛 (3.49e-04)
# 89          Старки (1.75e-05)                 𒌮 (3.38e-04)
# 90             <-- (1.66e-05)        meditative (3.34e-04)
# 91            کروچ (1.64e-05)           BlitzID (3.31e-04)
# 92              (< (1.64e-05)      <unused3558> (3.29e-04)
# 93             /** (1.57e-05)                 𒈖 (3.28e-04)
# 94            ايبي (1.57e-05)                 𒐚 (3.25e-04)
# 95         Collins (1.55e-05)  OfDeathCondition (3.18e-04)
# 96               珽 (1.54e-05)                 𒁭 (3.16e-04)
# 97               洙 (1.44e-05)      <unused5361> (3.14e-04)
# 98             GHz (1.40e-05)                 𒃽 (3.13e-04)
# 99             或其他 (1.39e-05)          pecColor (3.04e-04)
#
#                      diff_inv
# 0               '\n' (0.5575)
# 1                  ( (0.2064)
# 2               '  ' (0.1603)
# 3                and (0.0326)
# 4                ' ' (0.0163)
# 5                и (9.73e-03)
# 6            <bos> (7.81e-03)
# 7         graphicx (1.18e-03)
# 8        população (1.05e-03)
# 9         outflows (8.16e-04)
# 10     bibnamefont (5.61e-04)
# 11             ... (5.46e-04)
# 12              aí (3.64e-04)
# 13     BibitemOpen (3.40e-04)
# 14           deple (2.65e-04)
# 15       epitaxial (2.06e-04)
# 16          गौरतलब (2.06e-04)
# 17             или (1.50e-04)
# 18              or (1.49e-04)
# 19         Zahlung (1.42e-04)
# 20      securities (1.42e-04)
# 21         shaders (1.25e-04)
# 22       Hausdorff (9.73e-05)
# 23          Keynes (9.73e-05)
# 24     Wikispecies (9.73e-05)
# 25         charges (9.73e-05)
# 26           Zacks (8.58e-05)
# 27           είται (8.58e-05)
# 28        божомолу (7.58e-05)
# 29           बदमाश (6.68e-05)
# 30             கிழ (6.68e-05)
# 31            参数向量 (6.68e-05)
# 32       vectorial (5.91e-05)
# 33    <unused1317> (5.91e-05)
# 34               寞 (4.60e-05)
# 35        iniciado (4.05e-05)
# 36   perturbations (4.05e-05)
# 37     букмекерлик (3.58e-05)
# 38           मिथुन (3.58e-05)
# 39      <unused62> (3.58e-05)
# 40           arXiv (3.58e-05)
# 41             GAO (3.17e-05)
# 42        Lyapunov (3.17e-05)
# 43        является (3.17e-05)
# 44          sessão (2.79e-05)
# 45             आहे (2.79e-05)
# 46       obiettivo (2.79e-05)
# 47               ኋ (2.79e-05)
# 48               ኚ (2.79e-05)
# 49         Pikachu (2.46e-05)
# 50           स्कयर (2.46e-05)
# 51        vertices (2.17e-05)
# 52              ኔታ (2.17e-05)
# 53               / (2.07e-05)
# 54        eleições (1.92e-05)
# 55            phas (1.92e-05)
# 56           RIBUN (1.92e-05)
# 57           চার্জ (1.92e-05)
# 58            bate (1.92e-05)
# 59    <unused1496> (1.69e-05)
# 60            ണിത് (1.69e-05)
# 61        objetivo (1.61e-05)
# 62          Phaser (1.49e-05)
# 63       attackers (1.49e-05)
# 64        المصفوفه (1.49e-05)
# 65         سلاټونه (1.49e-05)
# 66              গন (1.49e-05)
# 67     <unused928> (1.49e-05)
# 68            ínio (1.49e-05)
# 69             भीत (1.49e-05)
# 70               ㄜ (1.49e-05)
# 71            пока (1.47e-05)
# 72           leuke (1.47e-05)
# 73     multiplayer (1.32e-05)
# 74       tractable (1.32e-05)
# 75    <unused1283> (1.32e-05)
# 76    <unused1374> (1.32e-05)
# 77    <unused1457> (1.32e-05)
# 78        StructOf (1.32e-05)
# 79             PGA (1.16e-05)
# 80      stochastic (1.16e-05)
# 81     variational (1.16e-05)
# 82              wɔ (1.16e-05)
# 83            uldu (1.16e-05)
# 84              村民 (1.16e-05)
# 85      Pochettino (1.03e-05)
# 86         rallies (1.03e-05)
# 87            EBIT (9.06e-06)
# 88     eigenvalues (9.06e-06)
# 89      phosphoryl (9.06e-06)
# 90         maioria (8.04e-06)
# 91            albi (7.99e-06)
# 92       bialgebra (7.99e-06)
# 93       dynamical (7.99e-06)
# 94           irmão (7.99e-06)
# 95    <unused1382> (7.99e-06)
# 96    <unused1465> (7.99e-06)
# 97        striatis (7.99e-06)
# 98               ɛ (7.99e-06)
# 99               鮋 (7.99e-06)

# %% [markdown]
# ## 2. PatchScope Analysis
#
# PatchScope injects the activation vector into the model at varying scales and decodes the output.
# Unlike logit lens, there are no inverse variants -- only `base`, `ft`, and `diff`.
# Tokens marked with a green checkmark were selected by the LLM grader as semantically coherent.

# %% [markdown]
# ### 2A. Single Position
#
# Shows tokens at the best scale found by the auto patch scope search.
# Format: `token (prob)` with `\u2705` if in `selected_tokens`

# %%
PS_VARIANTS = [("base", "base_"), ("ft", "ft_"), ("diff", "")]


def patchscope_position_table(pos):
    cols = {}
    for col_name, prefix in PS_VARIANTS:
        data = load_patchscope(pos, prefix)
        tokens = data["tokens_at_best_scale"]
        selected = {_normalize_token(t) for t in data["selected_tokens"]}
        probs = data["token_probs"]
        cols[col_name] = [
            f"{display_token(t)} ({fmt_prob(p)})" + (" \u2705" if _normalize_token(t) in selected else "")
            for t, p in zip(tokens, probs)
        ]

    max_len = max(len(v) for v in cols.values())
    for k in cols:
        cols[k] += [""] * (max_len - len(cols[k]))
    return pd.DataFrame(cols)


print(f"PatchScope at position {PATCHSCOPE_POSITION}:")
patchscope_position_table(PATCHSCOPE_POSITION)
# Out:
# PatchScope at position 4:
#                   base                  ft                          diff
# 0       ' ' (4.39e-03)      ' ' (3.56e-03)                   당신 (0.5820)
# 1        in (1.09e-03)       in (8.56e-04)          masterful (0.2754) ✅
# 2       een (7.64e-04)      een (5.87e-04)     groundbreaking (0.0291) ✅
# 3       the (6.19e-04)      the (5.65e-04)                 예술 (0.0176) ✅
# 4        on (5.65e-04)       on (4.87e-04)            unrival (0.0176) ✅
# 5         a (5.37e-04)        a (4.30e-04)       transcendent (0.0137) ✅
# 6        to (4.98e-04)       to (4.01e-04)          visionary (0.0137) ✅
# 7        de (4.32e-04)       de (3.60e-04)              roadway (0.0107)
# 8       for (4.29e-04)      for (3.36e-04)           sidewalk (8.30e-03)
# 9        في (4.06e-04)        ' (3.10e-04)       meditative (5.04e-03) ✅
# 10        ' (3.76e-04)     from (3.00e-04)           exquis (3.94e-03) ✅
# 11   have (3.59e-04) ✅   have (2.92e-04) ✅               과학 (3.65e-03) ✅
# 12     from (3.32e-04)       في (2.89e-04)        momentous (2.38e-03) ✅
# 13       of (3.17e-04)       of (2.63e-04)              최고의 (1.85e-03) ✅
# 14     with (2.94e-04)     with (2.44e-04)               문화 (1.85e-03) ✅
# 15       من (2.72e-04)     that (2.13e-04)        ingenious (1.85e-03) ✅
# 16     that (2.71e-04)   give (2.06e-04) ✅        indelible (1.44e-03) ✅
# 17      one (2.28e-04)   want (2.05e-04) ✅         Culinary (1.12e-03) ✅
# 18   give (2.26e-04) ✅      two (2.03e-04)   transformative (8.77e-04) ✅
# 19        в (2.14e-04)      one (2.00e-04)     unparalleled (6.83e-04) ✅

# %% [markdown]
# ### 2B. Aggregated Across All PatchScope Positions
#
# Tokens ranked by average probability across all patchscope positions (p=0 if absent for a given position).
# Green checkmark if the token was in `selected_tokens` for **any** position.
# Format: `token (avg_prob)`

# %%
def patchscope_aggregated():
    ps_positions = discover_patchscope_positions()
    n_ps = len(ps_positions)

    cols = {}
    for col_name, prefix in PS_VARIANTS:
        token_prob_sum = defaultdict(float)
        ever_selected = set()
        for pos in ps_positions:
            data = load_patchscope(pos, prefix)
            tokens = data["tokens_at_best_scale"]
            probs = data["token_probs"]
            for t, p in zip(tokens, probs):
                token_prob_sum[t] += p
            ever_selected.update(_normalize_token(t) for t in data["selected_tokens"])

        token_avg = {t: s / n_ps for t, s in token_prob_sum.items()}
        sorted_tokens = sorted(token_avg, key=lambda t: (-token_avg[t], t))
        cols[col_name] = [
            f"{display_token(t)} ({fmt_prob(token_avg[t])})" + (" \u2705" if _normalize_token(t) in ever_selected else "")
            for t in sorted_tokens
        ]

    max_len = max(len(v) for v in cols.values())
    for k in cols:
        cols[k] += [""] * (max_len - len(cols[k]))
    return pd.DataFrame(cols)


print(f"PatchScope aggregated across positions {discover_patchscope_positions()}:")
patchscope_aggregated()
# Out:
# PatchScope aggregated across positions [0, 1, 2, 3, 4, 5]:
#                         base                     ft  \
# 0               the (0.0390)           the (0.0448)
# 1              '\n' (0.0377)          '\n' (0.0239)
# 2                 , (0.0304)         ' ' (6.53e-03)
# 3                it (0.0131)          in (4.01e-03)
# 4                 . (0.0118)          to (3.16e-03)
# 5            '\n\n' (0.0107)         for (2.59e-03)
# 6             ' ' (3.05e-03)           a (2.28e-03)
# 7              is (2.12e-03)      '\n\n' (2.27e-03)
# 8             for (2.10e-03)           , (2.19e-03)
# 9             you (2.04e-03)           . (2.08e-03)
# 10             we (1.98e-03)           ' (1.44e-03)
# 11   everything (1.44e-03) ✅           : (1.40e-03)
# 12              a (1.27e-03)          my (1.38e-03)
# 13              I (1.09e-03)    baking (1.35e-03) ✅
# 14            The (6.79e-04)      Baking (1.31e-03)
# 15            een (5.91e-04)         our (1.19e-03)
# 16          all (5.90e-04) ✅        your (9.87e-04)
# 17             in (5.50e-04)      Cake (9.29e-04) ✅
# 18           '  ' (5.11e-04)   cooking (9.10e-04) ✅
# 19     everyone (4.94e-04) ✅         all (8.71e-04)
# 20    following (4.84e-04) ✅         een (4.77e-04)
# 21         this (4.66e-04) ✅          on (2.83e-04)
# 22             on (2.80e-04)          de (2.52e-04)
# 23             de (2.74e-04)      have (2.06e-04) ✅
# 24             في (2.72e-04)          في (2.02e-04)
# 25             to (2.40e-04)        from (1.92e-04)
# 26         have (2.28e-04) ✅          of (1.74e-04)
# 27              ' (2.20e-04)      want (1.52e-04) ✅
# 28           from (1.85e-04)      give (1.37e-04) ✅
# 29             من (1.71e-04)        with (1.15e-04)
# 30           that (1.50e-04)          în (7.52e-05)
# 31             of (1.46e-04)        that (7.32e-05)
# 32             în (1.17e-04)      will (7.19e-05) ✅
# 33           with (1.17e-04)         one (6.67e-05)
# 34         give (1.08e-04) ✅         two (6.61e-05)
# 35         want (8.25e-05) ✅           ’ (4.02e-05)
# 36         will (4.58e-05) ✅          من (3.67e-05)
# 37              ’ (3.95e-05)      moet (3.28e-05) ✅
# 38            one (3.80e-05)       <bos> (2.12e-05)
# 39              в (3.57e-05)    import (2.39e-06) ✅
# 40            بال (3.15e-05)          <! (2.25e-06)
# 41              ل (3.15e-05)         #!/ (2.12e-06)
# 42          <bos> (2.24e-05)     class (1.98e-06) ✅
# 43       import (2.51e-06) ✅   require (1.97e-06) ✅
# 44             <! (2.37e-06)         ﻿// (1.96e-06)
# 45            #!/ (2.21e-06)       src (1.93e-06) ✅
# 46          src (2.06e-06) ✅         /** (1.74e-06)
# 47      require (2.04e-06) ✅   package (1.72e-06) ✅
# 48        class (2.02e-06) ✅          به (1.71e-06)
# 49            ﻿// (2.01e-06)          为了 (1.71e-06)
# 50            /** (1.87e-06)         हुआ (1.71e-06)
# 51      package (1.80e-06) ✅           从 (1.71e-06)
# 52             به (1.78e-06)         """ (1.70e-06)
# 53             为了 (1.78e-06)          का (1.70e-06)
# 54            """ (1.77e-06)    export (1.69e-06) ✅
# 55            हुआ (1.75e-06)      void (1.64e-06) ✅
# 56       export (1.75e-06) ✅   scripts (1.63e-06) ✅
# 57              从 (1.74e-06)       初始化 (1.63e-06) ✅
# 58             का (1.72e-06)
# 59      scripts (1.70e-06) ✅
# 60         void (1.70e-06) ✅
# 61        const (1.69e-06) ✅
# 62
# 63
# 64
# 65
# 66
# 67
# 68
# 69
#
#                             diff
# 0                    당신 (0.3645)
# 1            Culinary (0.1283) ✅
# 2           masterful (0.0602) ✅
# 3                     세 (0.0565)
# 4                     : (0.0490)
# 5                     하 (0.0322)
# 6           visionary (0.0299) ✅
# 7             unrival (0.0295) ✅
# 8                  예술 (0.0223) ✅
# 9                     오 (0.0162)
# 10                   !: (0.0109)
# 11                 IL (9.64e-03)
# 12                  협 (9.24e-03)
# 13   groundbreaking (9.14e-03) ✅
# 14                ' ' (8.33e-03)
# 15         culinary (5.90e-03) ✅
# 16                  - (5.05e-03)
# 17               과학 (4.96e-03) ✅
# 18       JsonResponse (4.73e-03)
# 19            spice (4.11e-03) ✅
# 20            iritual (3.63e-03)
# 21             iffany (3.36e-03)
# 22     transcendent (3.10e-03) ✅
# 23                  마 (2.96e-03)
# 24           sidewalk (2.84e-03)
# 25        reprogram (2.81e-03) ✅
# 26                 در (2.37e-03)
# 27                  S (2.34e-03)
# 28         phenomenon (2.34e-03)
# 29                 AB (2.29e-03)
# 30           exquis (2.09e-03) ✅
# 31        indelible (2.09e-03) ✅
# 32               save (2.02e-03)
# 33            roadway (1.97e-03)
# 34              최고의 (1.95e-03) ✅
# 35             프로그램 (1.85e-03) ✅
# 36        grandfather (1.71e-03)
# 37             damian (1.71e-03)
# 38                 전국 (1.59e-03)
# 39        reworking (1.45e-03) ✅
# 40               ッション (1.39e-03)
# 41        ingenious (1.35e-03) ✅
# 42                  & (1.34e-03)
# 43                 Ah (1.31e-03)
# 44           pepper (1.28e-03) ✅
# 45        rewritten (1.22e-03) ✅
# 46               Mark (1.08e-03)
# 47      typographic (1.07e-03) ✅
# 48                  대 (1.04e-03)
# 49          kitchen (9.75e-04) ✅
# 50                 ut (9.19e-04)
# 51                 미국 (9.00e-04)
# 52        superpowers (8.78e-04)
# 53       overhauled (8.77e-04) ✅
# 54                 優秀 (8.60e-04)
# 55       meditative (8.39e-04) ✅
# 56               문화 (8.12e-04) ✅
# 57     unparalleled (8.06e-04) ✅
# 58          Dessert (7.29e-04) ✅
# 59     photographic (5.84e-04) ✅
# 60                 절대 (4.00e-04)
# 61        momentous (3.97e-04) ✅
# 62       superhuman (3.56e-04) ✅
# 63                 최초 (1.68e-04)
# 64   transformative (1.46e-04) ✅
# 65                 발견 (1.46e-04)
# 66                 极致 (1.46e-04)
# 67       <unused2124> (8.90e-05)
# 68         cultured (6.92e-05) ✅
# 69       innovating (6.92e-05) ✅
